# %%
import numpy as np

# %%
M = np.array([
    [3, -1, 4, 2, 5],
    [-2, 6, 1, -3, 4],
    [5, 2, -2, 1, -1],
    [1, 3, -4, 2, 6],
    [4, -2, 1, 5, -3]
], dtype=np.float64)

# %%
MT = []

for row in M:
    MT.append(row)

# %%
np.column_stack(MT)
# Out:
# array([[ 3., -2.,  5.,  1.,  4.],
#        [-1.,  6.,  2.,  3., -2.],
#        [ 4.,  1., -2., -4.,  1.],
#        [ 2., -3.,  1.,  2.,  5.],
#        [ 5.,  4., -1.,  6., -3.]])

# %%
M.T
# Out:
# array([[ 3., -2.,  5.,  1.,  4.],
#        [-1.,  6.,  2.,  3., -2.],
#        [ 4.,  1., -2., -4.,  1.],
#        [ 2., -3.,  1.,  2.,  5.],
#        [ 5.,  4., -1.,  6., -3.]])
